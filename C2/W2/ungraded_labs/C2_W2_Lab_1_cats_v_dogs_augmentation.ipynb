# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2024-09-28 10:24:56.612574: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-28 10:24:56.827939: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-28 10:24:57.514640: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-28 10:24:59.485896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
BASE_DIR = 'cats_and_dogs_filtered'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['train', 'validation']
#
# Contents of train directory: ['cats', 'dogs']
#
# Contents of validation directory: ['cats', 'dogs']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# 100/100 - 46s - 462ms/step - accuracy: 0.5175 - loss: 0.6922 - val_accuracy: 0.5050 - val_loss: 0.6827
# Epoch 2/20
# 100/100 - 43s - 429ms/step - accuracy: 0.5770 - loss: 0.6771 - val_accuracy: 0.5610 - val_loss: 0.6842
# Epoch 3/20
# 100/100 - 48s - 485ms/step - accuracy: 0.5965 - loss: 0.6624 - val_accuracy: 0.5750 - val_loss: 0.6801
# Epoch 4/20
# 100/100 - 45s - 453ms/step - accuracy: 0.6355 - loss: 0.6407 - val_accuracy: 0.6440 - val_loss: 0.6407
# Epoch 5/20
# 100/100 - 37s - 367ms/step - accuracy: 0.6700 - loss: 0.6120 - val_accuracy: 0.6910 - val_loss: 0.5898
# Epoch 6/20
# 100/100 - 36s - 359ms/step - accuracy: 0.6920 - loss: 0.5793 - val_accuracy: 0.6780 - val_loss: 0.5883
# Epoch 7/20
# 100/100 - 41s - 411ms/step - accuracy: 0.7245 - loss: 0.5547 - val_accuracy: 0.6800 - val_loss: 0.5844
# Epoch 8/20
# 100/100 - 36s - 358ms/step - accuracy: 0.7335 - loss: 0.5358 - val_accuracy: 0.6720 - val_loss: 0.6102
# Epoch 9/20
# 100/100 - 39s - 394ms/step - accuracy: 0.7485 - loss: 0.5188 - val_accuracy: 0.6960 - val_loss: 0.5561
# Epoch 10/20
# 100/100 - 34s - 342ms/step - accuracy: 0.7560 - loss: 0.4998 - val_accuracy: 0.7070 - val_loss: 0.5633
# Epoch 11/20
# 100/100 - 35s - 350ms/step - accuracy: 0.7675 - loss: 0.4740 - val_accuracy: 0.6910 - val_loss: 0.5841
# Epoch 12/20
# 100/100 - 41s - 407ms/step - accuracy: 0.7755 - loss: 0.4690 - val_accuracy: 0.7230 - val_loss: 0.5370
# Epoch 13/20
# 100/100 - 36s - 362ms/step - accuracy: 0.7960 - loss: 0.4408 - val_accuracy: 0.6900 - val_loss: 0.5989
# Epoch 14/20
# 100/100 - 40s - 404ms/step - accuracy: 0.8010 - loss: 0.4225 - val_accuracy: 0.7380 - val_loss: 0.5219
# Epoch 15/20
# 100/100 - 35s - 351ms/step - accuracy: 0.8190 - loss: 0.4011 - val_accuracy: 0.7360 - val_loss: 0.5219
# Epoch 16/20
# 100/100 - 36s - 357ms/step - accuracy: 0.8335 - loss: 0.3689 - val_accuracy: 0.7380 - val_loss: 0.5145
# Epoch 17/20
# 100/100 - 34s - 344ms/step - accuracy: 0.8385 - loss: 0.3578 - val_accuracy: 0.7490 - val_loss: 0.5076
# Epoch 18/20
# 100/100 - 35s - 346ms/step - accuracy: 0.8510 - loss: 0.3392 - val_accuracy: 0.7470 - val_loss: 0.5044
# Epoch 19/20
# 100/100 - 34s - 341ms/step - accuracy: 0.8635 - loss: 0.3121 - val_accuracy: 0.7480 - val_loss: 0.5250
# Epoch 20/20
# 100/100 - 34s - 343ms/step - accuracy: 0.8800 - loss: 0.2936 - val_accuracy: 0.7430 - val_loss: 0.5392

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augementation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20
# 2024-09-28 10:48:40.061645: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# 100/100 - 41s - 407ms/step - accuracy: 0.4990 - loss: 0.6938 - val_accuracy: 0.5000 - val_loss: 0.6955
# Epoch 2/80
# 100/100 - 41s - 412ms/step - accuracy: 0.5260 - loss: 0.6910 - val_accuracy: 0.5400 - val_loss: 0.6824
# Epoch 3/80
# 100/100 - 80s - 804ms/step - accuracy: 0.5620 - loss: 0.6846 - val_accuracy: 0.6140 - val_loss: 0.6698
# Epoch 4/80
# 100/100 - 40s - 404ms/step - accuracy: 0.5605 - loss: 0.6798 - val_accuracy: 0.6470 - val_loss: 0.6578
# Epoch 5/80
# 100/100 - 40s - 396ms/step - accuracy: 0.5920 - loss: 0.6656 - val_accuracy: 0.6240 - val_loss: 0.6439
# Epoch 6/80
# 100/100 - 41s - 412ms/step - accuracy: 0.5965 - loss: 0.6631 - val_accuracy: 0.6530 - val_loss: 0.6296
# Epoch 7/80
# 100/100 - 88s - 881ms/step - accuracy: 0.6035 - loss: 0.6529 - val_accuracy: 0.6030 - val_loss: 0.6354
# Epoch 8/80
# 100/100 - 48s - 482ms/step - accuracy: 0.6280 - loss: 0.6433 - val_accuracy: 0.5900 - val_loss: 0.6498
# Epoch 9/80
# 100/100 - 74s - 742ms/step - accuracy: 0.6235 - loss: 0.6376 - val_accuracy: 0.6620 - val_loss: 0.6020
# Epoch 10/80
# 100/100 - 40s - 402ms/step - accuracy: 0.6555 - loss: 0.6258 - val_accuracy: 0.6690 - val_loss: 0.5856
# Epoch 11/80
# 100/100 - 40s - 399ms/step - accuracy: 0.6645 - loss: 0.6133 - val_accuracy: 0.6900 - val_loss: 0.5744
# Epoch 12/80
# 100/100 - 40s - 399ms/step - accuracy: 0.6465 - loss: 0.6202 - val_accuracy: 0.7040 - val_loss: 0.5690
# Epoch 13/80
# 100/100 - 40s - 401ms/step - accuracy: 0.6610 - loss: 0.6104 - val_accuracy: 0.6610 - val_loss: 0.5876
# Epoch 14/80
# 100/100 - 40s - 400ms/step - accuracy: 0.6655 - loss: 0.6049 - val_accuracy: 0.7000 - val_loss: 0.5750
# Epoch 15/80
# 100/100 - 40s - 404ms/step - accuracy: 0.6905 - loss: 0.5963 - val_accuracy: 0.7040 - val_loss: 0.5605
# Epoch 16/80
# 100/100 - 51s - 506ms/step - accuracy: 0.6815 - loss: 0.5959 - val_accuracy: 0.6490 - val_loss: 0.6080
# Epoch 17/80
# 100/100 - 51s - 507ms/step - accuracy: 0.6770 - loss: 0.5900 - val_accuracy: 0.6380 - val_loss: 0.6593
# Epoch 18/80
# 100/100 - 46s - 463ms/step - accuracy: 0.6880 - loss: 0.5945 - val_accuracy: 0.6120 - val_loss: 0.6596
# Epoch 19/80
# 100/100 - 75s - 754ms/step - accuracy: 0.6820 - loss: 0.5925 - val_accuracy: 0.7030 - val_loss: 0.5585
# Epoch 20/80
# 100/100 - 40s - 400ms/step - accuracy: 0.6870 - loss: 0.5862 - val_accuracy: 0.7050 - val_loss: 0.5538
# Epoch 21/80
# 100/100 - 43s - 426ms/step - accuracy: 0.6995 - loss: 0.5806 - val_accuracy: 0.6990 - val_loss: 0.5655
# Epoch 22/80
# 100/100 - 81s - 807ms/step - accuracy: 0.6870 - loss: 0.5830 - val_accuracy: 0.6730 - val_loss: 0.5816
# Epoch 23/80
# 100/100 - 41s - 408ms/step - accuracy: 0.6940 - loss: 0.5815 - val_accuracy: 0.6720 - val_loss: 0.5804
# Epoch 24/80
# 100/100 - 42s - 419ms/step - accuracy: 0.7005 - loss: 0.5781 - val_accuracy: 0.7150 - val_loss: 0.5397
# Epoch 25/80
# 100/100 - 40s - 403ms/step - accuracy: 0.6885 - loss: 0.5801 - val_accuracy: 0.7100 - val_loss: 0.5443
# Epoch 26/80
# 100/100 - 41s - 411ms/step - accuracy: 0.7095 - loss: 0.5611 - val_accuracy: 0.7250 - val_loss: 0.5445
# Epoch 27/80
# 100/100 - 42s - 423ms/step - accuracy: 0.7050 - loss: 0.5695 - val_accuracy: 0.7200 - val_loss: 0.5368
# Epoch 28/80
# 100/100 - 37s - 369ms/step - accuracy: 0.7125 - loss: 0.5559 - val_accuracy: 0.7170 - val_loss: 0.5423
# Epoch 29/80
# 100/100 - 37s - 369ms/step - accuracy: 0.7125 - loss: 0.5645 - val_accuracy: 0.6850 - val_loss: 0.5812
# Epoch 30/80
# 100/100 - 41s - 407ms/step - accuracy: 0.7060 - loss: 0.5661 - val_accuracy: 0.6680 - val_loss: 0.5882
# Epoch 31/80
# 100/100 - 37s - 366ms/step - accuracy: 0.7020 - loss: 0.5559 - val_accuracy: 0.7320 - val_loss: 0.5177
# Epoch 32/80
# 100/100 - 37s - 367ms/step - accuracy: 0.7095 - loss: 0.5518 - val_accuracy: 0.7270 - val_loss: 0.5242
# Epoch 33/80
# 100/100 - 38s - 383ms/step - accuracy: 0.7140 - loss: 0.5594 - val_accuracy: 0.7250 - val_loss: 0.5248
# Epoch 34/80
# 100/100 - 38s - 381ms/step - accuracy: 0.7125 - loss: 0.5470 - val_accuracy: 0.6840 - val_loss: 0.5668
# Epoch 35/80
# 100/100 - 42s - 416ms/step - accuracy: 0.7175 - loss: 0.5476 - val_accuracy: 0.6700 - val_loss: 0.5993
# Epoch 36/80
# 100/100 - 39s - 390ms/step - accuracy: 0.7255 - loss: 0.5381 - val_accuracy: 0.7310 - val_loss: 0.5206
# Epoch 37/80
# 100/100 - 37s - 372ms/step - accuracy: 0.7315 - loss: 0.5369 - val_accuracy: 0.7410 - val_loss: 0.5177
# Epoch 38/80
# 100/100 - 37s - 368ms/step - accuracy: 0.7425 - loss: 0.5289 - val_accuracy: 0.7330 - val_loss: 0.5164
# Epoch 39/80
# 100/100 - 37s - 366ms/step - accuracy: 0.7290 - loss: 0.5412 - val_accuracy: 0.7220 - val_loss: 0.5301
# Epoch 40/80
# 100/100 - 37s - 368ms/step - accuracy: 0.7300 - loss: 0.5370 - val_accuracy: 0.7540 - val_loss: 0.5040
# Epoch 41/80
# 100/100 - 37s - 368ms/step - accuracy: 0.7245 - loss: 0.5366 - val_accuracy: 0.7500 - val_loss: 0.5141
# Epoch 42/80
# 100/100 - 37s - 370ms/step - accuracy: 0.7325 - loss: 0.5324 - val_accuracy: 0.7430 - val_loss: 0.4998
# Epoch 43/80
# 100/100 - 36s - 364ms/step - accuracy: 0.7350 - loss: 0.5266 - val_accuracy: 0.7520 - val_loss: 0.4960
# Epoch 44/80
# 100/100 - 35s - 352ms/step - accuracy: 0.7255 - loss: 0.5383 - val_accuracy: 0.7570 - val_loss: 0.5004
# Epoch 45/80
# 100/100 - 41s - 407ms/step - accuracy: 0.7305 - loss: 0.5300 - val_accuracy: 0.6990 - val_loss: 0.5517
# Epoch 46/80
# 100/100 - 37s - 368ms/step - accuracy: 0.7390 - loss: 0.5196 - val_accuracy: 0.7280 - val_loss: 0.5348
# Epoch 47/80
# 100/100 - 35s - 349ms/step - accuracy: 0.7300 - loss: 0.5226 - val_accuracy: 0.7570 - val_loss: 0.4943
# Epoch 48/80
# 100/100 - 35s - 350ms/step - accuracy: 0.7400 - loss: 0.5255 - val_accuracy: 0.7360 - val_loss: 0.5149
# Epoch 49/80
# 100/100 - 35s - 351ms/step - accuracy: 0.7370 - loss: 0.5139 - val_accuracy: 0.7430 - val_loss: 0.4999
# Epoch 50/80
# 100/100 - 35s - 351ms/step - accuracy: 0.7505 - loss: 0.5114 - val_accuracy: 0.7400 - val_loss: 0.4992
# Epoch 51/80
# 100/100 - 35s - 354ms/step - accuracy: 0.7415 - loss: 0.5142 - val_accuracy: 0.7570 - val_loss: 0.4945
# Epoch 52/80
# 100/100 - 32s - 322ms/step - accuracy: 0.7525 - loss: 0.5073 - val_accuracy: 0.7110 - val_loss: 0.5524
# Epoch 53/80
# 100/100 - 39s - 385ms/step - accuracy: 0.7500 - loss: 0.5112 - val_accuracy: 0.7620 - val_loss: 0.4888
# Epoch 54/80
# 100/100 - 41s - 408ms/step - accuracy: 0.7505 - loss: 0.5162 - val_accuracy: 0.7550 - val_loss: 0.4836
# Epoch 55/80
# 100/100 - 41s - 407ms/step - accuracy: 0.7560 - loss: 0.5039 - val_accuracy: 0.7500 - val_loss: 0.4980
# Epoch 56/80
# 100/100 - 32s - 317ms/step - accuracy: 0.7560 - loss: 0.5038 - val_accuracy: 0.7460 - val_loss: 0.5074
# Epoch 57/80
# 100/100 - 30s - 296ms/step - accuracy: 0.7555 - loss: 0.5033 - val_accuracy: 0.7540 - val_loss: 0.5158
# Epoch 58/80
# 100/100 - 32s - 316ms/step - accuracy: 0.7440 - loss: 0.5100 - val_accuracy: 0.7210 - val_loss: 0.5411
# Epoch 59/80
# 100/100 - 30s - 297ms/step - accuracy: 0.7430 - loss: 0.5159 - val_accuracy: 0.7730 - val_loss: 0.4966
# Epoch 60/80
# 100/100 - 43s - 428ms/step - accuracy: 0.7600 - loss: 0.4954 - val_accuracy: 0.7510 - val_loss: 0.4997
# Epoch 61/80
# 100/100 - 41s - 411ms/step - accuracy: 0.7555 - loss: 0.5055 - val_accuracy: 0.7600 - val_loss: 0.4780
# Epoch 62/80
# 100/100 - 32s - 320ms/step - accuracy: 0.7515 - loss: 0.5040 - val_accuracy: 0.7780 - val_loss: 0.4731
# Epoch 63/80
# 100/100 - 38s - 381ms/step - accuracy: 0.7560 - loss: 0.4944 - val_accuracy: 0.7510 - val_loss: 0.4860
# Epoch 64/80
# 100/100 - 29s - 295ms/step - accuracy: 0.7510 - loss: 0.5003 - val_accuracy: 0.7640 - val_loss: 0.4933
# Epoch 65/80
# 100/100 - 43s - 429ms/step - accuracy: 0.7620 - loss: 0.4952 - val_accuracy: 0.7670 - val_loss: 0.4685
# Epoch 66/80
# 100/100 - 30s - 299ms/step - accuracy: 0.7590 - loss: 0.4932 - val_accuracy: 0.7700 - val_loss: 0.4650
# Epoch 67/80
# 100/100 - 40s - 402ms/step - accuracy: 0.7580 - loss: 0.4936 - val_accuracy: 0.7550 - val_loss: 0.4795
# Epoch 68/80
# 100/100 - 30s - 298ms/step - accuracy: 0.7695 - loss: 0.4887 - val_accuracy: 0.7670 - val_loss: 0.4700
# Epoch 69/80
# 100/100 - 29s - 294ms/step - accuracy: 0.7715 - loss: 0.4810 - val_accuracy: 0.7630 - val_loss: 0.4797
# Epoch 70/80
# 100/100 - 29s - 294ms/step - accuracy: 0.7630 - loss: 0.4870 - val_accuracy: 0.7740 - val_loss: 0.4660
# Epoch 71/80
# 100/100 - 30s - 298ms/step - accuracy: 0.7680 - loss: 0.4884 - val_accuracy: 0.7430 - val_loss: 0.4871
# Epoch 72/80
# 100/100 - 30s - 297ms/step - accuracy: 0.7585 - loss: 0.4871 - val_accuracy: 0.7650 - val_loss: 0.4697
# Epoch 73/80
# 100/100 - 30s - 296ms/step - accuracy: 0.7710 - loss: 0.4739 - val_accuracy: 0.7800 - val_loss: 0.4716
# Epoch 74/80
# 100/100 - 30s - 298ms/step - accuracy: 0.7625 - loss: 0.4905 - val_accuracy: 0.7570 - val_loss: 0.5049
# Epoch 75/80
# 100/100 - 41s - 406ms/step - accuracy: 0.7665 - loss: 0.4754 - val_accuracy: 0.7620 - val_loss: 0.4791
# Epoch 76/80
# 100/100 - 47s - 472ms/step - accuracy: 0.7695 - loss: 0.4794 - val_accuracy: 0.7520 - val_loss: 0.5008
# Epoch 77/80
# 100/100 - 32s - 325ms/step - accuracy: 0.7680 - loss: 0.4726 - val_accuracy: 0.7680 - val_loss: 0.4712
# Epoch 78/80
# 100/100 - 34s - 342ms/step - accuracy: 0.7710 - loss: 0.4778 - val_accuracy: 0.7790 - val_loss: 0.4599
# Epoch 79/80
# 100/100 - 40s - 396ms/step - accuracy: 0.7590 - loss: 0.4788 - val_accuracy: 0.7700 - val_loss: 0.4735
# Epoch 80/80
# 100/100 - 38s - 375ms/step - accuracy: 0.7755 - loss: 0.4694 - val_accuracy: 0.7630 - val_loss: 0.4747

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!

# %%
# Shutdown the kernel to free up resources. 
# Note: You can expect a pop-up when you run this cell. You can safely ignore that and just press `Ok`.

from IPython import get_ipython

k = get_ipython().kernel

k.do_shutdown(restart=False)
# Out:
# {'status': 'ok', 'restart': False}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
